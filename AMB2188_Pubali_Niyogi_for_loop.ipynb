# %%
m=[10,20,30,40]
print("soil moisure is")
for i in m:
  print(i,"% moisture cmtent" )
# Out:
# soil moisure is
# 10 % moisture cmtent
# 20 % moisture cmtent
# 30 % moisture cmtent
# 40 % moisture cmtent

# %%
print("Maximum soil moisture= ", max(m),"%")
print("Minimum soil moisture",min(m),"%")
# Out:
# Maximum soil moisture=  40 %
# Minimum soil moisture 10 %

# %%
m=[10,20,30,40]
n=len(m)
print(n)
a=(a+m)
avg=a/n
print("Average soil moisture is",a)
# Out:
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2184013285.py in <cell line: 0>()
#       2 n=len(m)
#       3 print(n)
# ----> 4 a=(a+m)
#       5 avg=a/n
#       6 print("Average soil moisture is",a)
#
# NameError: name 'a' is not defined

# %%
name=["Pubali","Nanditha","Rakshitha"]
age=[22,21,20]
for i in range(len(name)):
  print(name[i],"'s age is : ",age[i])
# Out:
# Pubali 's age is :  22
# Nanditha 's age is :  21
# Rakshitha 's age is :  20

# %%
name=["nanditha","pragna","kruthi"]
age=[21,32,10]
for i in range(len(name)):
  print(name[i],"and age is", age[i])
# Out:
# nanditha and age is 21
# pragna and age is 32
# kruthi and age is 10

# %%
name=["Pubali","Nanditha","Rakshitha"]
age=[22,21,20]
for i in range(len(name.reverse())):
  print(name[i],"'s age is : ",age[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1590840980.py in <cell line: 0>()
#       1 name=["Pubali","Nanditha","Rakshitha"]
#       2 age=[22,21,20]
# ----> 3 for i in range(len(name.reverse())):
#       4   print(name[i],"'s age is : ",age[i])
#
# TypeError: object of type 'NoneType' has no len()

# %%
name=["nanditha","pragna","kruthi"]
age=[21,32,10]
for i in range(len(name)):
  print(name[i],"and age is", age[i])
# Out:
# nanditha and age is 21
# pragna and age is 32
# kruthi and age is 10

# %%
name=["Pubali","Nanditha","Rakshitha"]
age=[22,21,20]
for n,a in zip(name,age):
  print(n, "age is", a)
# Out:
# Pubali age is 22
# Nanditha age is 21
# Rakshitha age is 20

# %%
name=["nanditha","pragna","kruthi"]
age=[21,32,10]
for n,a in zip(name,age):
  print("name is ",n,"age is",a)
# Out:
# name is  nanditha age is 21
# name is  pragna age is 32
# name is  kruthi age is 10

# %%
crops=["rice","wheat","milet","maize","pules"]
water_needed=[300,200,100,150,80]
print(len(crops))
print("range",range(len(crops)))
for i in range(len(crops)):
  print(crops[i],"-", water_needed[i])
# Out:
# 5
# range range(0, 5)
# rice - 300
# wheat - 200
# milet - 100
# maize - 150
# pules - 80

# %%
crops=["rice","wheat","milet","maize","pules"]
water_needed=[300,200,100,150,80]
print(len(crops))
print("range",range(len(crops)))
for c,w in zip(crops,water_needed):
  print(c,"water needed is",w)
# Out:
# 5
# range range(0, 5)
# rice water needed is 300
# wheat water needed is 200
# milet water needed is 100
# maize water needed is 150
# pules water needed is 80

# %%
crops=['mango','banana','citrus']
water_need=[300,200,100]
print("Crop and water requirement :")
for c,w in zip(crops,water_need):
  print(c,"-",w,"mm")
# Out:
# Crop and water requirement :
# mango - 300 mm
# banana - 200 mm
# citrus - 100 mm

# %%
print("Crops needing high water (>180mm)")
for i in range(len(water_need)):
  if water_need[i]>180:
    print(crops[i])
# Out:
# Crops needing high water (>180mm)
# mango
# banana

# %%
crops=['mango','banana','citrus']
water_need=[300,200,100]
print("Crops needing high water (>180mm)")
for i,m in zip(crops,water_need):
  if m >180:
    print(i,"-",m)
# Out:
# Crops needing high water (>180mm)
# mango - 300
# banana - 200

# %%
crops=["rice","wheat","milet","maize","pules"]
water_needed=[300,200,100,150,80]
print("crops which need (>180)mm water is")
for i in range(len(water_needed)):
  if water_needed[i] >180:
    print(crops[i],"-",water_needed[i])
# Out:
# crops which need (>180)mm water is
# rice - 300
# wheat - 200

# %%
c=["rice","wheat","milet","maize","pulses"]
w=[300,200,100,150,80]
avg=sum(w)/len(w)
print("Average moisture requirement= ",avg)
# Out:
# Average moisture requirement=  166.0

# %%
crops=["rice","wheat","milet","maize","pules"]
water_needed=[300,200,100,150,80]
for i,m in zip(crops,water_needed):
  if m>180:
    print(i,m)
# Out:
# rice 300
# wheat 200

# %%
crops=["rice","wheat","milet","maize","pules"]
water_needed=[300,200,100,150,80]
avg=sum(water_needed)/len(water_needed)
print(avg)
# Out:
# 166.0

# %%
crops=["rice","wheat","milet","maize","pules"]
water_need=[300,200,100,150,80]
max_water=max(water_need)
index=water_need.index(max_water)
print("crop with highest water requirment:",crops[index])
max_crop=max(zip(water_need,crops))
print("crops with highest water requirment:",max_crop[0])
# Out:
# crop with highest water requirment: rice
# crops with highest water requirment: 300

# %%
c=["rice","wheat","milet","maize","pules"]
w=[300,200,100,150,80]
mw=max(w)
index=w.index(mw)
print("Crop with highest water requirement is: ",c[index])
# Out:
# Crop with highest water requirement is:  rice

# %%
c=["rice","wheat","milet","maize","pules"]
w=[300,200,100,150,80]
mc=max(zip(w,c))
print(mc)
print("Crop with highest water requirement: ",mc[1])
# Out:
# (300, 'rice')
# Crop with highest water requirement:  rice

# %%
c=["rice","wheat","milet","maize","pules"]
w=[300,200,100,150,80]
print(max(zip(w,c)))
print("Crop with highest water requirement: ",max(zip(w,c))[1])
# Out:
# (300, 'rice')
# Crop with highest water requirement:  rice

# %%
c=["rice","wheat","milet","maize","pules"]
y=[3.5,2.0,4.0,6.5,2.0]
my=max(y)
index=y.index(my)
print("Crop with highest yield: ",c[index])
# Out:
# Crop with highest yield:  maize

# %%
c=["rice","wheat","milet","maize","pules"]
y=[3.5,2.0,4.0,6.5,2.0]
print(max(zip(y,c)))
print("crops with highest yield: ",max(zip(y,c))[1])
# Out:
# (6.5, 'maize')
# crops with highest yield:  maize

# %%
c=["rice","wheat","milet","maize","pules"]
y=[3.5,2.0,4.0,6.5,2.0]
mc=max(zip(y,c))
print("crops with highest yield: ",mc[1])
# Out:
# crops with highest yield:  maize

# %%
c=["rice","wheat","milet","maize","pules"]
y=[3.5,2.0,4.0,6.5,2.0]
max_yeild=max(y)
index=y.index(max_yeild)
print("crp wih high yeild",c[index])
# Out:
# crp wih high yeild maize

# %%
c=["rice","wheat","millet","maize","pulses"]
y=[3.5,2.0,4.0,6.5,2.0]
avg=sum(y)/len(y)
print(avg)
for i in range(len(y)):
  if y[i]>avg:
    print(c[i])
# Out:
# 3.6
# millet
# maize

# %%
c=["rice","wheat","millet","maize","pulses"]
y=[3.5,2.0,4.0,6.5,2.0]
avg=sum(y)/len(y)
print(avg)
for i in range(len(c)):
  if y[i]>avg:
    print(c[i])
# Out:
# 3.6
# millet
# maize

# %%
c=["rice","wheat","millet","maize","pulses"]
y=[3.5,2.0,4.0,6.5,2.0]
avg=sum(y)/len(y)
for i,j in zip(y,c):
  if y[i] >avg:
    print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1721916368.py in <cell line: 0>()
#       3 avg=sum(y)/len(y)
#       4 for i,j in zip(y,c):
# ----> 5   if y[i] >avg:
#       6     print(c)
#
# TypeError: list indices must be integers or slices, not float

# %%
c=["rice","wheat","millet","maize","pulses"]
f=["urea","DAP","SSP","MOP","SOP"]
for i,j in zip(c,f):
  print(i,"-",j)
# Out:
# rice - urea
# wheat - DAP
# millet - SSP
# maize - MOP
# pulses - SOP

# %%
c=["rice","wheat","millet","maize","pulses"]
f=["urea","DAP","SSP","MOP","SOP"]
for i in range (len(f)):
    print (c[i],f[i])
# Out:
# rice urea
# wheat DAP
# millet SSP
# maize MOP
# pulses SOP
