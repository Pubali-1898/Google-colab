# %%
file=open("abc.txt","r")
content=file.read()
print(content)  #unless anything is not saved in abc filse it will throw error
file.close()
# Out:
# Hello India

# %%
file=open("abc.txt","w")
file.write("Hello India")  #if there is no content in the file .write() will create it and if already content was there it will relace the old one
file.close()

# %%
file=open("GKVK.txt","w")
file.write("College of Agriculture")
file.close()

# %%
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# College of Agriculture

# %%
file=open("GKVK.txt","a")
file.write("\nNature's heartbeat")
file.close()

# %%
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# College of AgricultureHeart of Bangalore
# Heart of Bangalore
# Nature's heartbeat

# %%
#using readlines()
file=open("GKVK.txt","r")
content=file.readlines()   # all lines have been given in the form of list
print(content)
file.close()
# Out:
# ['College of AgricultureHeart of Bangalore\n', 'Heart of Bangalore\n', "Nature's heartbeat"]

# %%
file=open("GKVK.txt","r")
content=file.readline()   # giving only the first line
print(content)
file.close()
# Out:
# College of AgricultureHeart of Bangalore

# %%
with open("GKVK.txt","r") as file:
  print(file.read())
# Out:
# College of AgricultureHeart of Bangalore
# Heart of Bangalore
# Nature's heartbeat

# %%
with open("GKVK.txt","w") as file:
  file.write("\nAwesome location")

# %%
with open("GKVK.txt","a") as file:
  file.write("\nResearch Hub")

# %%
with open("GKVK.txt","r") as file:
  print(file.read())
# Out:
# Awesome locationResearch Hub

# %%
#Exception handling with files
try:
  file=open("xyz.txt","r")
  c=file.read()
  print(c)
  file.close()
except:
  print("No such file exists")
# Out:
# No such file exists

# %%
try:
  with open("xyz.txt","r"):
    print(file.read())
except:
  print("No such file exists!!")
# Out:
# No such file exists!!

# %%
a=10
b=20
c=a+d
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-618493526.py in <cell line: 0>()
#       1 a=10
#       2 b=20
# ----> 3 c=a+d
#       4 print(c)
#
# NameError: name 'd' is not defined

# %%
try:
  a=10
  b=20
  c=a+d
  print(c)
except:
  print("some issue is there")
# Out:
# some issue is there

# %%
# program to do division using function
def num(a,b):
  c=a/b
  print(c)

num(100,20)
# Out:
# 5.0

# %%
def num(a,b):
  c=a/b
  print(c)

x=100
y=20
num(x,y)
# Out:
# 5.0

# %%
def num(a=100,b=5):
  c=a/b
  print(c)

d=num(x,y)
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-563489337.py in <cell line: 0>()
#       3   print(c)
#       4
# ----> 5 d=num(x,y)
#       6 print(d)
#
# NameError: name 'x' is not defined

# %%
def num(a,b):
  c=a/d
  print(c)

num(100,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1083665670.py in <cell line: 0>()
#       3   print(c)
#       4
# ----> 5 num(100,20)
#
# /tmp/ipython-input-1083665670.py in num(a, b)
#       1 def num(a,b):
# ----> 2   c=a/d
#       3   print(c)
#       4
#       5 num(100,20)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'NoneType'

# %%
def num(a,b):
  try:
    c=a/d
  except ZeroDivisionError:
    print("divided by 0")
  except NameError:
    print("Variable not declared")
  except:
    print("Some eror has occured")
  else:
    print("Exceuted without any error")
    print("Value of c is",c)
  finally:
    print("End of the program")

x=100
y=20
num(x,y)
# Out:
# Some eror has occured
# End of the program

# %%
def num(a,b):
  try:
    c=a/b
  except ZeroDivisionError:
    print("divided by 0")
  except NameError:
    print("Variable not declared")
  except:
    print("Some eror has occured")
  else:
    print("Exceuted without any error")
    print("Value of c is",c)
  finally:
    print("End of the program")

x=100
y=20
num(x,y)
# Out:
# Exceuted without any error
# Value of c is 5.0
# End of the program

# %%
def num(a,b):
  try:
    c=a/b
  except ZeroDivisionError:
    print("divided by 0")
  except NameError:
    print("Variable not declared")
  except:
    print("Some eror has occured")
  else:
    print("Exceuted without any error")
    print("Value of c is",c)
  finally:
    print("End of the program")

x=100
y=0
num(x,y)
# Out:
# divided by 0
# End of the program

# %%
def num(a,b):
  try:
     d=a/d
  except ZeroDivisionError:
    print("divided by 0")
  except NameError:
    print("Variable not declared")
  except:
    print("Some eror has occured")
  else:
    print("Exceuted without any error")
    print("Value of c is",c)
  finally:
    print("End of the program")

x=100
y=20
num(x,y)
# Out:
# Variable not declared
# End of the program

# %%
def num(a,b):
  try:
    c=a/d
  except ZeroDivisionError:
    print("divided by 0")
  except NameError:
    print("Variable not declared")
  except:
    print("Some eror has occured")
  else:
    print("Exceuted without any error")
    print("Value of c is",c)
  finally:
    print("End of the program")

x=0
y=20
num(x,y)
# Out:
# Some eror has occured
# End of the program
